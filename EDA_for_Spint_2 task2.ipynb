# %%
import pandas as pd

# %%
ls
# Out:
# EDA for Spint 2.ipynb  data_test.csv          price.csv
# calendar.csv           data_train.csv         sample_submission.csv

# %%
calender=pd.read_csv("calendar.csv")
calender
# Out:
#            date  wm_yr_wk    weekday  wday  month  year       d  event_name_1  \
# 0     1/29/2011     11101   Saturday     1      1  2011     d_1           NaN
# 1     1/30/2011     11101     Sunday     2      1  2011     d_2           NaN
# 2     1/31/2011     11101     Monday     3      1  2011     d_3           NaN
# 3      2/1/2011     11101    Tuesday     4      2  2011     d_4           NaN
# 4      2/2/2011     11101  Wednesday     5      2  2011     d_5           NaN
# ...         ...       ...        ...   ...    ...   ...     ...           ...
# 1964  6/15/2016     11620  Wednesday     5      6  2016  d_1965           NaN
# 1965  6/16/2016     11620   Thursday     6      6  2016  d_1966           NaN
# 1966  6/17/2016     11620     Friday     7      6  2016  d_1967           NaN
# 1967  6/18/2016     11621   Saturday     1      6  2016  d_1968           NaN
# 1968  6/19/2016     11621     Sunday     2      6  2016  d_1969  NBAFinalsEnd
#
# ...

# %%
price=pd.read_csv("price.csv")
price
# Out:
#          store_id              item_id  wm_yr_wk  sell_price
# 0        STATE1_1  ENTERTAINMENT_1_001     11325        9.58
# 1        STATE1_1  ENTERTAINMENT_1_001     11326        9.58
# 2        STATE1_1  ENTERTAINMENT_1_001     11327        8.26
# 3        STATE1_1  ENTERTAINMENT_1_001     11328        8.26
# 4        STATE1_1  ENTERTAINMENT_1_001     11329        8.26
# ...           ...                  ...       ...         ...
# 4800939  STATE2_3         EDIBLE_3_827     11617        1.00
# 4800940  STATE2_3         EDIBLE_3_827     11618        1.00
# 4800941  STATE2_3         EDIBLE_3_827     11619        1.00
# 4800942  STATE2_3         EDIBLE_3_827     11620        1.00
# 4800943  STATE2_3         EDIBLE_3_827     11621        1.00
#
# [4800944 rows x 4 columns]

# %%
ss=pd.read_csv('sample_submission.csv')
ss
# Out:
#                                             id  F1  F2  F3  F4  F5  F6  F7  \
# 0      ENTERTAINMENT_1_001_STATE1_1_validation   0   0   0   0   0   0   0
# 1      ENTERTAINMENT_1_002_STATE1_1_validation   0   0   0   0   0   0   0
# 2      ENTERTAINMENT_1_003_STATE1_1_validation   0   0   0   0   0   0   0
# 3      ENTERTAINMENT_1_004_STATE1_1_validation   0   0   0   0   0   0   0
# 4      ENTERTAINMENT_1_005_STATE1_1_validation   0   0   0   0   0   0   0
# ...                                        ...  ..  ..  ..  ..  ..  ..  ..
# 60975      EDIBLES_3_823__ignore__3_evaluation   0   0   0   0   0   0   0
# 60976      EDIBLES_3_824__ignore__3_evaluation   0   0   0   0   0   0   0
# 60977      EDIBLES_3_825__ignore__3_evaluation   0   0   0   0   0   0   0
# 60978      EDIBLES_3_826__ignore__3_evaluation   0   0   0   0   0   0   0
# 60979      EDIBLES_3_827__ignore__3_evaluation   0   0   0   0   0   0   0
#
#        F8  F9  F10
# 0       0   0    0
# 1       0   0    0
# ...

# %%
data_test=pd.read_csv('data_test.csv')
data_test
# Out:
#                                            id              item_id  \
# 0     ENTERTAINMENT_1_001_STATE1_1_evaluation  ENTERTAINMENT_1_001
# 1     ENTERTAINMENT_1_002_STATE1_1_evaluation  ENTERTAINMENT_1_002
# 2     ENTERTAINMENT_1_003_STATE1_1_evaluation  ENTERTAINMENT_1_003
# 3     ENTERTAINMENT_1_004_STATE1_1_evaluation  ENTERTAINMENT_1_004
# 4     ENTERTAINMENT_1_005_STATE1_1_evaluation  ENTERTAINMENT_1_005
# ...                                       ...                  ...
# 2323         EDIBLE_1_215_STATE2_1_evaluation         EDIBLE_1_215
# 2324         EDIBLE_1_216_STATE2_1_evaluation         EDIBLE_1_216
# 2325         EDIBLE_1_217_STATE2_1_evaluation         EDIBLE_1_217
# 2326         EDIBLE_1_218_STATE2_1_evaluation         EDIBLE_1_218
# 2327         EDIBLE_1_219_STATE2_1_evaluation         EDIBLE_1_219
#
#               dept_id         cat_id  store_id state_id  d_1  d_2  d_3  d_4  \
# 0     ENTERTAINMENT_1  ENTERTAINMENT  STATE1_1   STATE1    0    0    0    0
# ...

# %%
data_train=pd.read_csv("data_train.csv")
data_train
# Out:
#                                            id              item_id  \
# 0     ENTERTAINMENT_1_001_STATE1_1_validation  ENTERTAINMENT_1_001
# 1     ENTERTAINMENT_1_002_STATE1_1_validation  ENTERTAINMENT_1_002
# 2     ENTERTAINMENT_1_003_STATE1_1_validation  ENTERTAINMENT_1_003
# 3     ENTERTAINMENT_1_004_STATE1_1_validation  ENTERTAINMENT_1_004
# 4     ENTERTAINMENT_1_005_STATE1_1_validation  ENTERTAINMENT_1_005
# ...                                       ...                  ...
# 6093         EDIBLE_3_823_STATE2_1_validation         EDIBLE_3_823
# 6094         EDIBLE_3_824_STATE2_1_validation         EDIBLE_3_824
# 6095         EDIBLE_3_825_STATE2_1_validation         EDIBLE_3_825
# 6096         EDIBLE_3_826_STATE2_1_validation         EDIBLE_3_826
# 6097         EDIBLE_3_827_STATE2_1_validation         EDIBLE_3_827
#
#               dept_id         cat_id  store_id state_id  d_1  d_2  d_3  d_4  \
# 0     ENTERTAINMENT_1  ENTERTAINMENT  STATE1_1   STATE1    0    0    0    0
# ...

# %%
'''
join calender with price .csvs [[using wm_yr_wk]]
and then  that/ price.scsv with data_train.csvs [[using item_id]]
'''
# Out:
# '\njoin calender with price .csvs [[using wm_yr_wk]]\nand then  that/ price.scsv with data_train.csvs [[using item_id]]\n'

# %%
merged1=calender.merge(price, on='wm_yr_wk')#.head()#(40)
merged1
# Out:
#                date  wm_yr_wk   weekday  wday  month  year       d  \
# 0         1/29/2011     11101  Saturday     1      1  2011     d_1
# 1         1/29/2011     11101  Saturday     1      1  2011     d_1
# 2         1/29/2011     11101  Saturday     1      1  2011     d_1
# 3         1/29/2011     11101  Saturday     1      1  2011     d_1
# 4         1/29/2011     11101  Saturday     1      1  2011     d_1
# ...             ...       ...       ...   ...    ...   ...     ...
# 33499888  6/19/2016     11621    Sunday     2      6  2016  d_1969
# 33499889  6/19/2016     11621    Sunday     2      6  2016  d_1969
# 33499890  6/19/2016     11621    Sunday     2      6  2016  d_1969
# 33499891  6/19/2016     11621    Sunday     2      6  2016  d_1969
# 33499892  6/19/2016     11621    Sunday     2      6  2016  d_1969
#
#           event_name_1 event_type_1  event_name_2 event_type_2  snap_STATE1  \
# 0                  NaN          NaN           NaN          NaN            0
# ...

# %%
# merged2=price.merge(data_train, on='item_id')
# merged2

# %% [markdown]
# ##  EDA for merged1:-

# %%
# merged1['weekday'].sum()

# %%
ORDER_STATUS=merged1.groupby(['weekday'],dropna=False).size().reset_index(name='counts').sort_values(by=['counts'],ascending=False)
ORDER_STATUS['%']=round(100*ORDER_STATUS['counts']/ORDER_STATUS['counts'].sum(),2)
ORDER_STATUS
# Out:
#      weekday   counts      %
# 2   Saturday  4800944  14.33
# 3     Sunday  4800944  14.33
# 0     Friday  4779601  14.27
# 1     Monday  4779601  14.27
# 4   Thursday  4779601  14.27
# 5    Tuesday  4779601  14.27
# 6  Wednesday  4779601  14.27

# %%
# fig=make_subplots(
# rows=2, cols=2,
# specs=[[]])
# fig.add_trace(go.Pie(values=ORDER['weekday'],name='Weekdays Counts Analysis',showlegend=True),row=2, col=1)

# %%
import matplotlib.pyplot as plt
import numpy as np
# plt.style.use('_mpl-gallery')

# make data:
np.random.seed(3)
x = ORDER_STATUS['weekday']
y = ORDER_STATUS['counts']

# plot
fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="white", linewidth=10.0)

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
  
# creating the dataset
# data = {'C':20, 'C++':15, 'Java':30,
#         'Python':35}
courses = ORDER_STATUS['weekday']
values = ORDER_STATUS['%']
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)
 
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %%
event_type_1=merged1.groupby(['event_type_1'],dropna=False).size().reset_index(name='counts').sort_values(by=['counts'],ascending=False)
event_type_1['%']=round(100*event_type_1['counts']/event_type_1['counts'].sum(),2)
event_type_1
# Out:
#   event_type_1    counts      %
# 4          NaN  30741455  91.77
# 2    Religious    933597   2.79
# 1     National    891867   2.66
# 0     Cultural    627900   1.87
# 3     Sporting    305074   0.91

# %% [markdown]
# ~Therefore  as we can see that around 91% data is having NAN values.

# %%
en1=merged1.groupby(['event_name_1'],dropna=False).size().reset_index(name='counts').sort_values(by=['counts'],ascending=False)
en1['%']=round(100*en1['counts']/en1['counts'].sum(),2)
en1
# Out:
#            event_name_1    counts      %
# 30                  NaN  30741455  91.77
# 24       Ramadan starts    105010   0.31
# 16         NBAFinalsEnd    104072   0.31
# 17       NBAFinalsStart    103738   0.31
# 14          MemorialDay    103526   0.31
# 15         Mother's day    102943   0.31
# 21           Pesach End    101774   0.30
# 25        StPatricksDay    100374   0.30
# 23            Purim End    100085   0.30
# 12            LentWeek2     99564   0.30
# 11            LentStart     99037   0.30
# 22        PresidentsDay     98559   0.29
# 28        ValentinesDay     98020   0.29
# 26            SuperBowl     97264   0.29
# 4                Easter     91189   0.27
# 13  MartinLutherKingDay     87934   0.26
# 19    OrthodoxChristmas     87570   0.26
# 18              NewYear     87306   0.26
# 1             Christmas     87108   0.26
# 0          Chanukah End     86979   0.26
# 27         Thanksgiving     86598   0.26
# 29          VeteransDay     86461   0.26
# ...

# %%
et2=merged1.groupby(['event_type_2'],dropna=False).size().reset_index(name='counts').sort_values(by=['counts'],ascending=False)
et2['%']=round(100*et2['counts']/et2['counts'].sum(),2)
et2
# Out:
#   event_type_2    counts      %
# 2          NaN  33412402  99.74
# 0     Cultural     68198   0.20
# 1    Religious     19293   0.06

# %%
en2=merged1.groupby(['event_name_2'],dropna=False).size().reset_index(name='counts').sort_values(by=['counts'],ascending=False)
en2['%']=round(100*en2['counts']/en2['counts'].sum(),2)
en2
# Out:
#      event_name_2    counts      %
# 4             NaN  33412402  99.74
# 2    Father's day     41048   0.12
# 3  OrthodoxEaster     19293   0.06
# 0   Cinco De Mayo     16628   0.05
# 1          Easter     10522   0.03

# %% [markdown]
# ~Therefore  as we can see that around 91% data is having NAN values.

# %%
st_id=merged1.groupby(['store_id'],dropna=False).size().reset_index(name='counts').sort_values(by=['counts'],ascending=False)
st_id['%']=round(100*st_id['counts']/st_id['counts'].sum(),2)
st_id
# Out:
#    store_id   counts      %
# 5  STATE2_2  4893253  14.61
# 4  STATE2_1  4883327  14.58
# 0  STATE1_1  4873639  14.55
# 2  STATE1_3  4842685  14.46
# 6  STATE2_3  4822539  14.40
# 3  STATE1_4  4737930  14.14
# 1  STATE1_2  4446520  13.27

# %%
item_id=merged1.groupby(['item_id'],dropna=False).size().reset_index(name='counts').sort_values(by=['counts'],ascending=False)
item_id['%']=round(100*item_id['counts']/item_id['counts'].sum(),2)
item_id

# item_id
# Out:
#                   item_id  counts     %
# 2026          HOUSE_1_025   13783  0.04
# 1769  ENTERTAINMENT_1_341   13783  0.04
# 1643  ENTERTAINMENT_1_213   13783  0.04
# 1639  ENTERTAINMENT_1_209   13783  0.04
# 505          EDIBLE_2_291   13783  0.04
# ...                   ...     ...   ...
# 2238          HOUSE_1_242    2940  0.01
# 423          EDIBLE_2_209    2758  0.01
# 908          EDIBLE_3_296    2618  0.01
# 2433          HOUSE_1_441    2072  0.01
# 593          EDIBLE_2_379    1687  0.01
#
# [3049 rows x 3 columns]

# %% [markdown]
# Therefore; we can see for many fields; there are a majority; rather a 99% data distribution of Nan values; which needs to be checked.

# %% [markdown]
# ## For data_train:-

# %%
data_train.head()
# Out:
#                                         id              item_id  \
# 0  ENTERTAINMENT_1_001_STATE1_1_validation  ENTERTAINMENT_1_001
# 1  ENTERTAINMENT_1_002_STATE1_1_validation  ENTERTAINMENT_1_002
# 2  ENTERTAINMENT_1_003_STATE1_1_validation  ENTERTAINMENT_1_003
# 3  ENTERTAINMENT_1_004_STATE1_1_validation  ENTERTAINMENT_1_004
# 4  ENTERTAINMENT_1_005_STATE1_1_validation  ENTERTAINMENT_1_005
#
#            dept_id         cat_id  store_id state_id  d_1  d_2  d_3  d_4  ...  \
# 0  ENTERTAINMENT_1  ENTERTAINMENT  STATE1_1   STATE1    0    0    0    0  ...
# 1  ENTERTAINMENT_1  ENTERTAINMENT  STATE1_1   STATE1    0    0    0    0  ...
# 2  ENTERTAINMENT_1  ENTERTAINMENT  STATE1_1   STATE1    0    0    0    0  ...
# 3  ENTERTAINMENT_1  ENTERTAINMENT  STATE1_1   STATE1    0    0    0    0  ...
# 4  ENTERTAINMENT_1  ENTERTAINMENT  STATE1_1   STATE1    0    0    0    0  ...
#
#    d_1904  d_1905  d_1906  d_1907  d_1908  d_1909  d_1910  d_1911  d_1912  \
# ...

# %%
item_id_train=data_train.groupby(['item_id'],dropna=False).size().reset_index(name='counts').sort_values(by=['counts'],ascending=False)
item_id_train['%']=round(100*item_id_train['counts']/item_id_train['counts'].sum(),2)
item_id_train

# item_id
# Out:
#            item_id  counts     %
# 0     EDIBLE_1_001       2  0.03
# 2036   HOUSE_1_036       2  0.03
# 2027   HOUSE_1_026       2  0.03
# 2028   HOUSE_1_027       2  0.03
# 2029   HOUSE_1_028       2  0.03
# ...            ...     ...   ...
# 1019  EDIBLE_3_407       2  0.03
# 1020  EDIBLE_3_408       2  0.03
# 1021  EDIBLE_3_409       2  0.03
# 1022  EDIBLE_3_410       2  0.03
# 3048   HOUSE_2_516       2  0.03
#
# [3049 rows x 3 columns]

# %% [markdown]
# For the data distribution for the "item_id" column/or/field.,;; we can see that most of the data is divided equally into/with 0.03 data percenmtage of distribution.

# %%
ids=data_train.groupby(['id'],dropna=False).size().reset_index(name='counts').sort_values(by=['counts'],ascending=False)
ids['%']=round(100*ids['counts']/ids['counts'].sum(),2)
ids
# Out:
#                                     id  counts     %
# 0     EDIBLE_1_001_STATE1_1_validation       1  0.02
# 4062   HOUSE_1_030_STATE1_1_validation       1  0.02
# 4071   HOUSE_1_035_STATE2_1_validation       1  0.02
# 4070   HOUSE_1_035_STATE1_1_validation       1  0.02
# 4069   HOUSE_1_034_STATE2_1_validation       1  0.02
# ...                                ...     ...   ...
# 2030  EDIBLE_3_403_STATE1_1_validation       1  0.02
# 2029  EDIBLE_3_402_STATE2_1_validation       1  0.02
# 2028  EDIBLE_3_402_STATE1_1_validation       1  0.02
# 2027  EDIBLE_3_401_STATE2_1_validation       1  0.02
# 6097   HOUSE_2_516_STATE2_1_validation       1  0.02
#
# [6098 rows x 3 columns]

# %% [markdown]
# For the data distribution for the "id" column/or/field.,;; we can see that most of the data is divided equally into/with 0.2 data percenmtage of distribution.

# %%
dept_id=data_train.groupby(['dept_id'],dropna=False).size().reset_index(name='counts').sort_values(by=['counts'],ascending=False)
dept_id['%']=round(100*dept_id['counts']/dept_id['counts'].sum(),2)
dept_id



# dept_id
# Out:
#            dept_id  counts      %
# 2         EDIBLE_3    1646  26.99
# 5          HOUSE_1    1064  17.45
# 6          HOUSE_2    1030  16.89
# 3  ENTERTAINMENT_1     832  13.64
# 1         EDIBLE_2     796  13.05
# 0         EDIBLE_1     432   7.08
# 4  ENTERTAINMENT_2     298   4.89

# %% [markdown]
# The highest type or the most commonly occuring dept_id data type is of that of:- 'EDIBLE_3' with a total of around 27% of the data distribution.

# %%
cat_id=data_train.groupby(['cat_id'],dropna=False).size().reset_index(name='counts').sort_values(by=['counts'],ascending=False)
cat_id['%']=round(100*cat_id['counts']/cat_id['counts'].sum(),2)
cat_id

# cat_id
# Out:
#           cat_id  counts      %
# 0         EDIBLE    2874  47.13
# 2          HOUSE    2094  34.34
# 1  ENTERTAINMENT    1130  18.53

# %% [markdown]
# Therefore; as we can see that the cat_ids have the following  distribution for all three the types of datas/categories present. Where; the higesht/or/ the most common datta type is EDIBLE which comprises of almost/nearly 50% of the entire dataset..

# %% [markdown]
# store_id=data_train.groupby(['store_id'],dropna=False).size().reset_index(name='counts').sort_values(by=['counts'],ascending=False)
# store_id['%']=round(100*store_id['counts']/store_id['counts'].sum(),2)
# store_id
#
#
# ## store_id;;;;

# %% [markdown]
# Therefore; as we can see that the store_ids have equal distribution for both the types of datas/categories present.

# %%
state_id=data_train.groupby(['state_id'],dropna=False).size().reset_index(name='counts').sort_values(by=['counts'],ascending=False)
state_id['%']=round(100*state_id['counts']/state_id['counts'].sum(),2)
state_id



#state_id
# Out:
#   state_id  counts     %
# 0   STATE1    3049  50.0
# 1   STATE2    3049  50.0

# %% [markdown]
# Therefore; as we can see that the state_ids have equal distribution for both the types of datas/categories present.

# %% [markdown]
# ## Feature engineering: preparation.,::--;;

# %% [markdown]
# for median salary:-

# %%
# merged['median_salary']=
merged1.shape
set1=set(merged1['date'])
set1

list1=list(set1)
list1
# list1_new=[]
# for i in list1:
#     if i not in list1_new:
#         list1_new.append(i)
# list1_new
# Out:
# ['1/18/2012',
#  '4/3/2015',
#  '12/13/2011',
#  '1/16/2012',
#  '3/31/2015',
#  '9/15/2014',
#  '11/30/2013',
#  '1/12/2012',
#  '7/15/2014',
#  '11/18/2014',
#  '11/11/2015',
#  '4/17/2015',
#  '4/6/2015',
#  '5/31/2011',
#  '4/9/2016',
#  '4/8/2014',
#  '3/6/2011',
#  '5/9/2016',
#  '10/20/2013',
#  '5/1/2011',
#  '6/12/2014',
#  '3/15/2015',
#  '4/6/2012',
#  '2/25/2013',
#  '6/1/2014',
#  '2/11/2013',
#  '10/4/2013',
#  '11/10/2013',
#  '12/15/2011',
#  '2/28/2011',
#  '3/31/2016',
#  '2/17/2013',
#  '10/28/2013',
#  '6/18/2011',
#  '3/31/2014',
#  '3/13/2015',
#  '12/4/2015',
#  '3/19/2015',
#  '2/7/2011',
#  '2/22/2012',
#  '11/27/2011',
#  '5/12/2013',
#  '6/6/2014',
#  '1/13/2012',
#  '11/14/2011',
#  '10/27/2011',
#  '5/27/2015',
#  '8/19/2014',
#  '7/26/2011',
#  '10/13/2012',
#  '4/11/2012',
#  '11/29/2015',
#  '6/10/2016',
#  '8/22/2013',
#  '2/13/2011',
#  '8/14/2013',
#  '8/8/2014',
#  '6/15/2016',
#  '10/2/2014',
#  '6/30/2012',
#  '3/3/2015',
#  '5/22/2014',
# ...

# %%
# a={}
# type(a)
# b=set()
# type(b)
# Out:
# set

# %%
# list1=[]
# for ind in merged1.index:
# #     print(df['Name'][ind], df['Stream'][ind])
#     if merged1['date'][ind] not in list1:
#         list1.append(merged1['date'][ind])
#         sals=[]
#         sals.append(merged1['sell_price'][ind])
#     else:
#         sals.append

# %%
merged1['median_salary']=0

list_new=[]
for i in list1:
    sub=merged1[merged1['date']==i]
    list_new.append( sub['sell_price'].median())
#     sub['median_price']=sub['sell_price'].median()
#     print(sub)
#     example.append(sub)
#     print(example)
# #     example['sell_price']=sub['sell_price']
# #     print(sub)
# # list_new
merged1['median_salary']=list_new
# # example
# #     example[example['date']==i]['median_price']=sub['median_price']
# example
# # sub
merged1

# %%
# merged1[merged1['date']=='1/29/2011']

# %%
# for i in list1:
#     sub=merged1[merged1['date']==i]
#     sub['median_salary']= sub['sell_price'].median()
# merged1

# %%
# example=merged1[(merged1['date']=='1/29/2011')|(merged1['date']=='1/31/2012')]
# example
# example['median_price']=0
# example

# %%
# list1=['1/29/2011','1/31/2012']
list1=list(example['date'])
list1
list_new=[]
for i in list1:
    sub=example[example['date']==i]
    list_new.append( sub['sell_price'].median())
#     sub['median_price']=sub['sell_price'].median()
#     print(sub)
#     example.append(sub)
#     print(example)
# #     example['sell_price']=sub['sell_price']
# #     print(sub)
# # list_new
example['median_salary']=list_new
# # example
# #     example[example['date']==i]['median_price']=sub['median_price']
# example
# # sub
example
# Out:
# <ipython-input-171-50f37e8d026c>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   example['median_salary']=list_new
#               date  wm_yr_wk   weekday  wday  month  year      d event_name_1  \
# 0        1/29/2011     11101  Saturday     1      1  2011    d_1          NaN
# 1        1/29/2011     11101  Saturday     1      1  2011    d_1          NaN
# 2        1/29/2011     11101  Saturday     1      1  2011    d_1          NaN
# 3        1/29/2011     11101  Saturday     1      1  2011    d_1          NaN
# 4        1/29/2011     11101  Saturday     1      1  2011    d_1          NaN
# ...            ...       ...       ...   ...    ...   ...    ...          ...
# ...

# %%
# df1 = df = pd.DataFrame({"a":[1, 2, 3, 4],
#                          "b":[5, 6, 7, 8]})
 
# # Creating the Second Dataframe using dictionary
# df2 = pd.DataFrame({"a":[1, 2, 3],
#                     "b":[5, 6, 7]})


# # to append df2 at the end of df1 dataframe
# df1.append(df2)
